            "entities": "```json\n[\n  {\n    \"entity\": \"\u041a\u043e\u043c\u043c\u0430\u043b\u043e\u0432\",\n    \"type\": \"Person\",\n    \"context\": \"A possibly early communist, whose origin and relatives are unknown; mentioned as a figure to be researched and remembered.\"\n  },\n  {\n    \"entity\": \"\u041f\u0440\u0435\u0441\u043b\u0430\u0432\",\n    \"type\": \"Place\",\n    \"context\": \"A location the author wishes to visit to restore memory of Kommalov and related historical figures; likely a town or city in Bulgaria (historically significant).\"\n  },\n  {\n    \"entity\": \"\u0412\u0430\u0440\u0431\u0430\u043d\u0435\u0446 \u041d\u0438\u043a\u043e\u043b\u0430\u0439\",\n    \"type\": \"Person\",\n    \"context\": \"The author's brother, also ill, from Mogilev; visited the museum in Pr\u0435\u0441lav on November 6th and reported back.\"\n  },\n  {\n    \"entity\": \"\u041c\u043e\u0433\u0438\u043b\u0435\u0432\",\n    \"type\": \"Place\",\n    \"context\": \"The hometown of Varnabets Nikolai, who is mentioned as having visited the museum in Pr\u0435\u0441lav.\"\n  },\n  {\n    \"entity\": \"6 \u043d\u043e\u044f\u0431\u0440\u044f\",\n    \"type\": \"Date\",\n    \"context\": \"The date when Varnabets Nikolai visited the museum in Pr\u0435\u0441lav.\"\n  },\n  {\n    \"entity\": \"\u0414\u043c\u0438\u0442\u0440\u0438\u0439 \u043d\u0430 \u0414.\u0411.\",\n    \"type\": \"Person\",\n    \"context\": \"A person named Dmitry, possibly associated with \"D.B.\" (possibly an abbreviation for a name or place); referenced in a photograph that may be relevant to the museum collection.\"\n  },\n  {\n    \"entity\": \"\u0415. \u0421\u0430\u043b\u0438\u0431\u0435\u043a\u043e\u0432\u0430\",\n    \"type\": \"Person\",\n    \"context\": \"The author of the letter, writing from Melitopol, seeking information about Kommalov and museum materials.\"\n  },\n  {\n    \"entity\": \"\u041c\u0435\u043b\u0438\u0442\u043e\u043f\u043e\u043b\u044c\",\n    \"type\": \"Place\",\n    \"context\": \"The current residence of the author, \u0415. \u0421\u0430\u043b\u0438\u0431\u0435\u043a\u043e\u0432\u0430; also mentioned as having a museum with internal correspondence.\"\n  },\n  {\n    \"entity\": \"\u043c\u0443\u0437\u0435\u0439\",\n    \"type\": \"Organization\",\n    \"context\": \"A museum in Pr\u0435\u0441lav (and possibly one in Melitopol) that holds historical documents and photographs, including potential records of Kommalov and others.\"\n  },\n  {\n    \"entity\": \"\u0412\u0430\u0440\u0431\u0430\u043b\u0435\u043d\u043e\",\n    \"type\": \"Person\",\n    \"context\": \"Possibly a misspelling or variant of \"Varnabets\" (referring to Nikolai Varnabets); mentioned in a letter found inside the Melitopol museum.\"\n  },\n  {\n    \"entity\": \"20\",\n    \"type\": \"Date\",\n    \"context\": \"Likely refers to the date \"20th\" (possibly of a month), mentioned in connection with a letter from Varnabets in the Melitopol museum.\"\n  }\n]\n```",
u0441\u043f\u0435\u0446\u0438\u0430\u043b\u044c\u043d\u043e \u0432 \u043c\u0443\u0437\u0435\u0439, \u0430 \u043f\u043e\u043a\u0430 \u044d\u0442\u043e \u043f\u043e-\u043d\u0435\u043c\u043d\u043e\u0433\u0443 \u0438\u043d\u0442\u0435\u0440\u0435\u0441\u043d\u0435\u0435, \u0433\u0434\u0435 \u0447\u0442\u043e \u043c\u043e\u0436\u043d\u043e \u0434\u043e\u0441\u0442\u0430\u0442\u044c \u0434\u043b\u044f \u043c\u0443\u0437\u0435\u044f. \u0424\u043e\u0442\u043e\u0433\u0440\u0430\u0444\u0438\u044f \u0441\u043d\u0438\u043c\u043e\u043a \u0414\u043c\u0438\u0442\u0440\u0438\u044f \u043d\u0430 \u0414.\u0411., \u0442\u0430\u043c \u0438 \u043d\u0435 \u0437\u043d\u0430\u043b\u0438 \u0432\u0438\u0434\u0430\u043b\u0438 \u0435\u0433\u043e \u0412\u0430\u043c.\n\n\u041d\u0430 \u044d\u0442\u043e\u043c \u0437\u0430\u043a\u0430\u043d\u0447\u0438\u0432\u0430\u044e, \u0438\u0437\u0432\u0438\u043d\u0438\u0442\u0435 \u0437\u0430 \u0431\u0435\u0441\u043f\u043e\u043a\u043e\u0439\u0441\u0442\u0432\u043e. \u0423\u0441\u043f\u0435\u0445\u0430 \u0432\u0430\u043c \u0432 \u0431\u043b\u0430\u0433\u043e\u0440\u043e\u0434\u043d\u043e\u043c \u0434\u0435\u043b\u0435!\n\n\u0421 \u043f\u0440\u0438\u0432\u0435\u0442\u043e\u043c: \u0415. \u0421\u0430\u043b\u0438\u0431\u0435\u043a\u043e\u0432\u0430.\n\u041c\u0435\u043b\u0438\u0442\u043e\u043f\u043e\u043b\u044c.\n\nP.S.\n\u0415\u0441\u0442\u044c \u043b\u0438 \u043f\u0435\u0440\u0435\u0447\u0435\u043d\u044c \u0440\u043e\u0434.  \n\u0411\u044b\u043b \u043a\u0442\u043e \u0432 \u043c\u0443\u0437\u0435\u0435,  \n\u043c\u043e\u0436\u043d\u043e \u043b\u0438  \n\u0437\u0430\u0431\u0440\u0430\u0442\u044c  \n\u0435\u0433\u043e?\n\n\u041c\u0435\u043b\u0438\u0442\u043e\u043f\u043e\u043b\u044c \u0435\u0441\u0442\u044c  \n\u043c\u0443\u0437\u0435\u0439 \u0438\u043c\u0435\u0435\u0442  \n\u0432\u043d\u0443\u0442\u0440\u0438 \u043f\u0438\u0441\u044c\u043c\u043e  \n\u0412\u0430\u0440\u0431\u0430\u043b\u0435\u043d\u043e  \n20.",
            "image_uri": "https://images.eap.bl.uk/EAP164/EAP164_1_18_1/4.jp2/full/full/0/default.jpg"
        }

# %%
bad_json = item['entities'] 
bad_json
# Out:
# '```json\n[\n  {\n    "entity": "Коммалов",\n    "type": "Person",\n    "context": "A possibly early communist, whose origin and relatives are unknown; mentioned as a figure to be researched and remembered."\n  },\n  {\n    "entity": "Преслав",\n    "type": "Place",\n    "context": "A location the author wishes to visit to restore memory of Kommalov and related historical figures; likely a town or city in Bulgaria (historically significant)."\n  },\n  {\n    "entity": "Варбанец Николай",\n    "type": "Person",\n    "context": "The author\'s brother, also ill, from Mogilev; visited the museum in Prесlav on November 6th and reported back."\n  },\n  {\n    "entity": "Могилев",\n    "type": "Place",\n    "context": "The hometown of Varnabets Nikolai, who is mentioned as having visited the museum in Prесlav."\n  },\n  {\n    "entity": "6 ноября",\n    "type": "Date",\n    "context": "The date when Varnabets Nikolai visited the museum in Prесlav."\n  },\n  {\n    "entity": "Дмитрий на Д.Б.
# ...

# %%
import json
import re
from typing import Any, Optional


def safe_parse_entities(entity_string: str) -> list:
    """
    Safely parse entity JSON, returning an empty list on failure.
    Designed for use in the entity_recognition workflow step.
    
    Args:
        entity_string: String that may contain entity JSON
        
    Returns:
        List of entity dictionaries, or empty list if parsing fails
    """
    output = []

    # Remove leading/trailing fence lines like ```json ... ``` (tolerant)
    s = entity_string.strip()
    if s.startswith('```'):
        # drop first fence line
        parts = s.split('\n', 1)
        if len(parts) == 2:
            s = parts[1]
        # drop trailing fence if present
        if s.endswith('```'):
            s = s[:-3].rstrip()

    # Try a strict JSON parse first (fast and correct when valid)
    try:
        parsed = json.loads(s)
        if isinstance(parsed, list):
            return parsed
        if isinstance(parsed, dict):
            return [parsed]
        return []
    except Exception:
        # fall through to tolerant parsing
        pass

    # Fallback: extract {...} blocks and parse fields tolerant to unescaped quotes
    blocks = re.findall(r'\{.*?\}', s, re.DOTALL)
    for block in blocks:
        ent = {}
        # entity and type are usually safe to capture with a simple regex
        m_entity = re.search(r'"entity"\s*:\s*"([^"]*)"', block)
        if m_entity:
            ent['entity'] = m_entity.group(1).strip()
        m_type = re.search(r'"type"\s*:\s*"([^"]*)"', block)
        if m_type:
            ent['type'] = m_type.group(1).strip()
        # context may contain unescaped quotes; capture between the first quote after the colon
        # and the last quote in the block (heuristic but works for this data)
        idx = block.find('"context"')
        if idx != -1:
            pos_col = block.find(':', idx)
            first_q = block.find('"', pos_col + 1)
            last_q = block.rfind('"')
            if first_q != -1 and last_q > first_q:
                context = block[first_q + 1:last_q]
                ent['context'] = context.strip()
        if ent:
            output.append(ent)

    return output

# update the notebook-level `result` variable with parsed entities
result = safe_parse_entities(bad_json)
result
# Out:
# [{'entity': 'Коммалов',
#   'type': 'Person',
#   'context': 'A possibly early communist, whose origin and relatives are unknown; mentioned as a figure to be researched and remembered.'},
#  {'entity': 'Преслав',
#   'type': 'Place',
#   'context': 'A location the author wishes to visit to restore memory of Kommalov and related historical figures; likely a town or city in Bulgaria (historically significant).'},
#  {'entity': 'Варбанец Николай',
#   'type': 'Person',
#   'context': "The author's brother, also ill, from Mogilev; visited the museum in Prесlav on November 6th and reported back."},
#  {'entity': 'Могилев',
#   'type': 'Place',
#   'context': 'The hometown of Varnabets Nikolai, who is mentioned as having visited the museum in Prесlav.'},
#  {'entity': '6 ноября',
#   'type': 'Date',
#   'context': 'The date when Varnabets Nikolai visited the museum in Prесlav.'},
#  {'entity': 'Дмитрий на Д.Б.',
#   'type': 'Person',
# ...
